# %% [markdown]
# <a href="https://colab.research.google.com/github/animaghosh10/Python-Training/blob/main/Python_Workshop.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ***Day-1***

# %%
import keyword
print("standrd keyword=", len(keyword.kwlist))
print("soft keyword=", keyword.softkwlist)
print("all keyword=",keyword.kwlist)
# Out:
# standrd keyword= 35
# soft keyword= ['_', 'case', 'match', 'type']
# all keyword= ['False', 'None', 'True', 'and', 'as', 'assert', 'async', 'await', 'break', 'class', 'continue', 'def', 'del', 'elif', 'else', 'except', 'finally', 'for', 'from', 'global', 'if', 'import', 'in', 'is', 'lambda', 'nonlocal', 'not', 'or', 'pass', 'raise', 'return', 'try', 'while', 'with', 'yield']

# %%
print("standrd keyword=", "No of keyword", len(keyword.kwlist))
# Out:
# standrd keyword= No of keyword 35

# %%
x=5
y="Python"
z=3.5
print (type(x))
print (type (y))
print (type(z))
# Out:
# <class 'int'>
# <class 'str'>
# <class 'float'>

# %%
y1=int(2)
y2=float(2)
y3=str(2)

print(y1)
print(y2)
print(y3)
# Out:
# 2
# 2.0
# 2

# %%
c=50
d=float (c)

print(d)
# Out:
# 50.0

# %%
y1=int(2)
y2=float(2)
y3=str(2)

print(y1)
print(y2)
print(y3)

print(type(y1))
print(type(y2))
print(type(y3))
# Out:
# 2
# 2.0
# 2
# <class 'int'>
# <class 'float'>
# <class 'str'>

# %%
y1=2
print(y1)
print(type(y1))

y2=float (y1)
print(y2)
print(type(y2))

y3=str (y1)
print(y3)
print(type(y3))
# Out:
# 2
# <class 'int'>
# 2.0
# <class 'float'>
# 2
# <class 'str'>

# %%
a=20
b=str(a)

print(type(b))
# Out:
# <class 'str'>

# %%
my_name="Anima"
my_dep= "BS"
my_University="SRU"

print(my_name)
print(my_dep)
print(my_University)
# Out:
# Anima
# BS
# SRU

# %%
a=input ("enter value of a")
b=input ("enter value of b")
a= (int(a))
b= (int(b))
print ("=================")
print ("simple calculator")
print ("=================")
print ("addition=",a+b)
print ("subtraction=",a-b)
print ("multiplication=",a*b)
print ("division=",a/b)
print ("modulus=",a%b)
print ("exponent=",a**b)
print ("floor division=",a//b)
# Out:
# enter value of a2
# enter value of b3
# =================
# simple calculator
# =================
# addition= 5
# subtraction= -1
# multiplication= 6
# division= 0.6666666666666666
# modulus= 2
# exponent= 8
# floor division= 0

# %% [markdown]
# # ***Day-2***

# %%
a=input ("Enter First Name")
b=input ("Enter Last Name")
print ("=================")
print ("Arthimatic Operaiton on strings")
print ("=================")
Full_Name=a+" " +b+" " #String Concatenation
print ("full name=", Full_Name)
repeat_name=Full_Name*2
print ("repeat_name=", repeat_name)
print ("==============")
# Out:
# Enter First NameAnima
# Enter Last NameGhosh
# =================
# Arthimatic Operaiton on strings
# =================
# full name= Anima Ghosh
# repeat_name= Anima Ghosh Anima Ghosh
# ==============

# %% [markdown]
# Precedence Operators

# %%
a=20
b=30
c=40
print ("Value1=", a+b*c)
print ("Value2=", (a+b)*c)
print ("Value3=",c/a+(b*2))
# Out:
# Value1= 1220
# Value2= 2000
# Value3= 62.0

# %% [markdown]
# Relation Operator

# %%
num1=10
num2=0
num3=10
str1="Good"
str2="Afternoon"
print("status=", num1==num2)
print("status=", num1==num3)
print("status=", num1!=num2)
print("status=", num1!=num3)
print("status=", num1>num2)
print("status=", num1<num3)
print("status=", num1<=num2)
print("status=", num1>=num3)
# Out:
# status= False
# status= True
# status= True
# status= False
# status= True
# status= False
# status= False
# status= True

# %% [markdown]
# logical operator

# %%
num1=10
num2=0
num3=10
print ("status=", num1==num2 and num1==num3)
print ("status=", num1==num2 or num1==num3)
print ("status=", not (num1>=num3))
# Out:
# status= False
# status= True
# status= False

# %% [markdown]
# Assignmnet Operator

# %%
num1=10
print("num1=", num1)
num2=num1
print("num2=", num2)
num2=20
print("num2=", num2)
num1+=num2  #num1=10+20
print ("num1=", num1)
num1-=num2 #num1=30-20
print ("num1=", num1)
num1*-num2 #num1=num1*num2
print("num1=", num1)
num1/num2 #num1=num1/num2
print ("num1=", num1)
num1%=num2 #num1=num1%num2
print ("num1=", num1)
# Out:
# num1= 10
# num2= 10
# num2= 20
# num1= 30
# num1= 10
# num1= 10
# num1= 10
# num1= 10

# %% [markdown]
# Membership operator

# %%
students=["anima", "Ghosh"]
call_attendance=input("call student name")
print("status=", call_attendance in students)
print("status=", call_attendance not in students)
# Out:
# call student nameanima
# status= True
# status= False

# %% [markdown]
# Bitwise Operation

# %%
a=10 #a=1010
b=5  #b=0101
print("results=", a&b)
print("results=", a|b)
print ("results",~a)
print ("results",~b)
print ("results",~b)
print ("result", a^b)
# Out:
# results= 0
# results= 15
# results -11
# results -6
# results -6
# result 15

# %% [markdown]
# same value, different object

# %%
a=2000
b=2000
print (a==b) # true (value are same)
print (a is b) # false (different object in memory)
# Out:
# True
# False

# %% [markdown]
# same object

# %%
a=[1,2,3]
b=a
print("a == b") #true (values are same)
print ("a is b") #true (same object in memory)
# Out:
# a == b
# a is b

# %%
a=[1,2,3]
b=a
c=[1,2,3]
print ("status=", a is b)
print ("status=", a is c)
print ("status=", a is not c)
# Out:
# status= True
# status= False
# status= True

# %%
userid=["ram, vvr"]
username=input("Input user name")
if(username in userid):
  print ("user exist")
else:
  print ("user not exist")
# Out:
# Input user nameram
# user not exist

# %%
#odd number check
num=input("enter number to check")
num=int(num)
if(num%2!=0):
  print(f"number {num} is odd")
# Out:
# enter number to check5
# number 5 is odd

# %%
#odd and even number check
num=input("enter number to check")
num=int(num)
if(num%2!=0):
  print(f"number {num} is odd")
else:
  print(f"number {num} is even")
# Out:
# enter number to check15
# number 15 is odd

# %% [markdown]
# If Else

# %%
num = int(input("Enter a number to check: "))
if num % 2 != 0:
    print(f"Number {num} is odd")
else:
    print(f"Number {num} is even")
# Out:
# Enter a number to check: 20
# Number 20 is even

# %%
#short hand If-else statement

marks=input("enter student marks")
marks=int(marks)
print("pass") if marks>=35 else print ("fail")
# Out:
# enter student marks45
# pass

# %% [markdown]
# nested if statements

# %%
marks=input("enter student marks")
marks=int(marks)
if marks>=35:
  print("student pass in subject grade")
if marks>60:
  print ("studnet D grade")
# Out:
# enter student marks75
# student pass in subject grade
# studnet D grade
